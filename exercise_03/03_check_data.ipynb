# %% [markdown]
# # **第3回 データの確認**
#
# コードを実行してください。
#
# ※上部にある「ドライブにコピー」で自分のドライブにコピーしてから編集・実行してください。

# %%
# pandasライブラリをインポート
import pandas as pd

# %%
# Googleドライブのマウント
from google.colab import drive
drive.mount('/content/drive')

# %%
# csvファイルの読み込み
# データをpandasのデータフレーム形式で読み込む
df = pd.read_csv('/content/drive/MyDrive/jts2024_3/data/train.csv')

# データの最初の10行を確認
print("【データの最初の10行】\n")
print(df.head(10))

# データ全体のサイズを確認
print("\n【データ全体のサイズ (画像数, 特徴数)】\n")
print(df.shape)

# ラベルが0（猫）のデータのサイズを確認
print("\n【猫のデータのサイズ (画像数, 特徴数)】\n")
print(df[df['label'] == 0].shape)

# ラベルが1（犬）のデータのサイズを確認
print("\n【犬のデータのサイズ (画像数, 特徴数)】\n")
print(df[df['label'] == 1].shape)
