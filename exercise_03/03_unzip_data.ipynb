# %% [markdown]
# # **第3回 データの解凍**
#
# コードを実行してください。
#
# ※上部にある「ドライブにコピー」で自分のドライブにコピーしてから編集・実行してください。

# %%
# Googleドライブのマウント
from google.colab import drive
drive.mount('/content/drive')

# %%
# train.zipの解凍
# !unzip -j drive/MyDrive/jts2024_3/train.zip -d drive/MyDrive/jts2024_3/data/all
