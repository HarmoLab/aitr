# %% [markdown]
# # Tutorial for OpenAI API
# 目次
# - OpenAI APIのインストール
# - 環境変数の設定
# - シンプルな文章生成
# - オープンデータセットを用いた文章分類
# - 課題1. 文章分類タスクの評価
# - Extra課題
#
# 注意点
# - この演習はGoogle Colaboratyで実行することを想定しています

# %% [markdown]
# ## OpenAI APIのインストール
# - [公式ドキュメント](https://platform.openai.com/docs/api-reference?lang=python)
# - [GitHub](https://github.com/openai/openai-python)

# %%
# ライブラリのインストール
# !pip install openai==1.3.3
# Out:
# Collecting openai==1.3.3
#   Downloading openai-1.3.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<4,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.3.3) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.3.3) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.3.3) (0.27.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.3.3) (2.9.2)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai==1.3.3) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.10/dist-packages (from openai==1.3.3) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai==1.3.3) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai==1.3.3) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai==1.3.3) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai==1.3.3) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai==1.3.3) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.3.3) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.3.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.3.3) (2.23.4)
# Downloading openai-1.3.3-py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.52.2
#     Uninstalling openai-1.52.2:
#       Successfully uninstalled openai-1.52.2
# Successfully installed openai-1.3.3

# %% [markdown]
# ## 環境変数の設定
# 左のタブの`シークレット`から`OPENAI_API_KEY`を設定
#
#
# <img width=500 src="https://github.com/HarmoLab/aitr/blob/main/2023/exercise_04/colab_secret.png?raw=true">

# %%
from google.colab import userdata
from openai import OpenAI

client = OpenAI(
    api_key= userdata.get('OPENAI_API_KEY')
)

# %%
# promptから料金を出力する関数
def calculate_credit(model:str, input_tokens:int, output_tokens:int) -> float:
    yen_rate = 150 # $1 = 150円で計算
    if model == "gpt-3.5-turbo-1106":
        input_credit = (0.001 * yen_rate) / 1000
        output_credit = (0.002 * yen_rate) / 1000
    elif model == "gpt-4-1106-preview":
        input_credit = (0.01 * yen_rate) / 1000
        output_credit = (0.03 * yen_rate) / 1000
    elif model == "gpt-4-turbo":
        input_credit = (0.01 * yen_rate) / 1000
        output_credit = (0.03 * yen_rate) / 1000
    elif model == "o1-preview":
        input_credit = (0.015 * yen_rate) / 1000
        output_credit = (0.06 * yen_rate) / 1000
    elif model == "o1-mini":
        input_credit = (0.003 * yen_rate) / 1000
        output_credit = (0.012 * yen_rate) / 1000
    elif model == "gpt-4o-mini-2024-07-18":
        input_credit = (0.0015 * yen_rate) / 1000
        output_credit = (0.003 * yen_rate) / 1000
    else:
        assert False, f"モデル名: {model}の料金計算はできません。modelは'gpt-3.5-turbo-1106',または'gpt-4-1106-preview'を使用してください。"
    total_credit = round(input_credit * input_tokens + output_credit * output_tokens, 2)
    print(f"使用したモデル: {model}, 料金: {total_credit}円")
    return total_credit

# %% [markdown]
# ## シンプルな文章生成
# - 公式ドキュメント
#     - 文章生成(text-generation): https://platform.openai.com/docs/guides/text-generation

# %%
user_prompt = "ChatGPTについて簡潔に3文で教えてください。" # ここを修正
model = "gpt-3.5-turbo-1106"

response = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": user_prompt
        },
    ],
    model=model,
    max_tokens=500,
    n=1,
    temperature=1,

)

# %%
print("--- レスポンス全体 ---")
print(response)

calculate_credit(model, response.usage.prompt_tokens, response.usage.completion_tokens)

print()
print("--- 質問 ---")
print(user_prompt)
print("--- 回答 ---")
print(response.choices[0].message.content)
# Out:
# --- レスポンス全体 ---
# ChatCompletion(id='chatcmpl-AQ5DFhxY3kkYIgYmheIPzg1ed6Jwr', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='ChatGPTは、自然言語処理を用いた会話エージェントです。人工知能を活用して、ユーザーとの会話を通じて質問に答えたり、情報を提供したりします。また、さまざまなトピックについて深い会話を行うことができます。', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730779929, model='gpt-3.5-turbo-1106', object='chat.completion', system_fingerprint='fp_e7d4a5f731', usage=CompletionUsage(completion_tokens=95, prompt_tokens=29, total_tokens=124, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 使用したモデル: gpt-3.5-turbo-1106, 料金: 0.03円
#
# --- 質問 ---
# ChatGPTについて簡潔に3文で教えてください。
# --- 回答 ---
# ChatGPTは、自然言語処理を用いた会話エージェントです。人工知能を活用して、ユーザーとの会話を通じて質問に答えたり、情報を提供したりします。また、さまざまなトピックについて深い会話を行うことができます。

# %% [markdown]
# ### chat.completions.createに使用する引数について
# 公式ドキュメント: https://platform.openai.com/docs/api-reference/chat/create
#
# ### 主要な引数
# - model (必須)
#     - 使用する学習モデル (本演習では"gpt-3.5-turbo-1106"を使用)
# - messages (必須)
#     - role
#         - system: アシスタントの動作を設定
#         - assistant: アシスタントの望ましい動作を設定 (ユーザも作成可)
#         - user: ユーザの指示
#     - content
#         - roleに対して入力する文章
# - max_tokens: int or null
#     - 生成するトークンの最大数。出力の長さを制限することが可能
# - n: int or null
#     - 生成するレスポンスの数 (デフォルト: 1)
# - temperature: number or null
#     - 0～2の間で指定
#     - 0に近づくにつれて決定論的になり、2に近づくにつれて生成文が多様でランダムになる（デフォルト: 1）
#         - 詳しい説明: https://techblog.a-tm.co.jp/entry/2023/04/24/181232

# %% [markdown]
# ## オープンデータセットを用いた文章分類
# - 今回使用するデータセット
#     - Amazon Reviews Multi:
# https://huggingface.co/datasets/mteb/amazon_reviews_multi/viewer/ja

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 7.2 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 3.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 6.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import datasets
# Amazonレビューのデータセット(日本語)をダウンロード
# 今回はダウンロード時間を減らすために検証データ (validation)のみ取得
dataset = datasets.load_dataset("mteb/amazon_reviews_multi", "ja", split="validation")
print(dataset)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/47.0 [00:00<?, ?B/s]
# amazon_reviews_multi.py:   0%|          | 0.00/6.17k [00:00<?, ?B/s]
# 0000.parquet:   0%|          | 0.00/40.7M [00:00<?, ?B/s]
# ja/validation/0000.parquet:   0%|          | 0.00/999k [00:00<?, ?B/s]
# 0000.parquet:   0%|          | 0.00/1.01M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/200000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Dataset({
#     features: ['id', 'text', 'label', 'label_text'],
#     num_rows: 5000
# })

# %%
# 実際のデータセットを確認
dataset[0]["text"]
# Out:
# '不良品\n\n味自体及び吸い心地は良いのだが、不良品が多過ぎる。私の場合５本のうち２本が蒸気も出ず、吸い込み も出来なかった。腹が立ってごみ箱行きでした。こんなものは２度と購入する気はない。 返品するのも交渉するのも、金額も金額だからと面倒くさがってしない方が多いのではないか？ 最初から不良品多しとでも表記しておいたら如何？'

# %%
system_prompt = "以下のレビュー文を評価してください"
user_prompt = dataset[0]["text"] # レビュー文のみ

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": user_prompt
        },
    ],
    model="gpt-3.5-turbo",
)

# %%
print("--- 全体の出力 ---")
print(response)

calculate_credit(model, response.usage.prompt_tokens, response.usage.completion_tokens)

print()
print("--- 質問 ---")
print(user_prompt)
print("--- 回答 ---")
print(response.choices[0].message.content)
# Out:
# --- 全体の出力 ---
# ChatCompletion(id='chatcmpl-AQ5DwJxXieGi4uGq5Tmzdnp2CtBVH', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='このレビューは製品の味や吸い心地について肯定的な意見を述べていますが、不良品が多いという点でマイナスの評価をしています。不良品が多いという問題は重要な点であり、消費者にとっては非常に不満足な経験となるでしょう。また、返品や交渉が金額や手間の問題で煩わしく感じられるという指摘もあります。改善点としては、製品が不良品である可能性を事前に明記することで、消費者の選択をサポートすることが挙げられます。このレビューは消費者にとって参考になる情報を提供していますが、改善点も示唆されているので、評価は詳細かつバランスのとれたものと言えるでしょう。', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730779972, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=280, prompt_tokens=192, total_tokens=472, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 使用したモデル: gpt-3.5-turbo-1106, 料金: 0.11円
#
# --- 質問 ---
# 不良品
#
# 味自体及び吸い心地は良いのだが、不良品が多過ぎる。私の場合５本のうち２本が蒸気も出ず、吸い込み も出来なかった。腹が立ってごみ箱行きでした。こんなものは２度と購入する気はない。 返品するのも交渉するのも、金額も金額だからと面倒くさがってしない方が多いのではないか？ 最初から不良品多しとでも表記しておいたら如何？
# --- 回答 ---
# このレビューは製品の味や吸い心地について肯定的な意見を述べていますが、不良品が多いという点でマイナスの評価をしています。不良品が多いという問題は重要な点であり、消費者にとっては非常に不満足な経験となるでしょう。また、返品や交渉が金額や手間の問題で煩わしく感じられるという指摘もあります。改善点としては、製品が不良品である可能性を事前に明記することで、消費者の選択をサポートすることが挙げられます。このレビューは消費者にとって参考になる情報を提供していますが、改善点も示唆されているので、評価は詳細かつバランスのとれたものと言えるでしょう。

# %%
from tenacity import (
    retry,
    stop_after_attempt,
    wait_random_exponential,
)

# forでループするために関数化 (RateLimit対策のためtenacityのデコーダを採用)
# 参考: https://cookbook.openai.com/examples/how_to_handle_rate_limits
@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(6))
def simple_completion(model_name, system_prompt:str, user_prompt:str):
    response = client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": system_prompt
            },
            {
                "role": "user",
                "content": user_prompt
            },
        ],
        model=model_name,
        timeout=15
    )
    # 料金の計算
    credit = calculate_credit(model_name, response.usage.prompt_tokens, response.usage.completion_tokens)
    return response, credit

# %% [markdown]
# ## 課題1. 文章分類タスクの評価
# system_promptを変更してレビュー文章を用いた評価値推定を行いましょう。

# %%
model_name = "gpt-4o-mini-2024-07-18" # モデル名
k = 30 # k件のレビュー文に対する評価
shuffled_dataset = dataset.shuffle(seed=70) # データセットをシャッフル
review_list = shuffled_dataset[:k]["text"]
label_list = shuffled_dataset[:k]["label"]
print(review_list)
print(label_list)

# 課題1: 正答率と評価値を上げるためのsystem_promptを考えましょう。
system_prompt = """
以下のレビュー文を5段階で評価してください。0~4の数字のみを出力してください。
"""
system_prompt = """
レビュー文を0から4までの整数に分類してください。

### 例 ###
レビュー文: ヒト由来の乳酸菌
体にもよさそうで値段も安いので喜んで食べてましたが、ふと、「ヒト由来」って何よ？と思い調べてみました。 製品ホームページにも詳しくは書いてないですが、 実は・・・から採取、分離、培養してるそうです。 お客様相談室にも確認しました。 うーーん。
2

レビュー文: お得感。ありました。温かそうで可愛いです。3.1kgチワワでMサイズで大丈夫でした。梱包も到着日も満足しています。
3

レビュー文: 商品がちゃんと届きません！定期お届け便でこの商品を購入しましたが、とにかく配送業者がいい加減で在宅してるのに不在票だけポストに入れて帰る。再配達依頼の電話に出ない。電話に出ても「はい。行きます。」と言ったっきり来ない等々で今月２１日到着予定が２７日になっても届きません。amazonに確認したところ配送業者の変更は出来ないとの事でしたのでクレーム入れてキャンセルしました。 どんなに良い商品でも届かないと意味がありません！
0

レビュー文: 梱包丁寧。メダカ元気。何匹かは到着した時には死んでいると思っていたけどそんな事はなく凄く元気でした。 今は卵から赤ちゃんが誕生しています。
3
"""

predict_label_list = [] # -1(出力形式のエラー), 0, 1, 2, 3, 4
total_credit = 0
for i, (review, label) in enumerate(zip(review_list, label_list)):
    print(f"\n^^^^^^^^^^ {i+1}件目のレビュー ^^^^^^^^^^")
    print("--- レビュー文 ---")
    print(review)
    print("--- 実際の評価 ---")
    print(label)
    response, credit = simple_completion(model_name, system_prompt, review)
    total_credit += credit
    print("--- ChatGPTの回答 ---")
    print(response)
    print(response.choices[0].message.content)

    try:
        response_int = int(response.choices[0].message.content)
        predict_label_list.append(response_int)
    except ValueError:
        print("--- Error ---")
        print("回答がint型に変換できませんでした。")
        predict_label_list.append(-1)
        continue
print(f"合計金額: {total_credit}円")
# Out:
# ['無難な一品\n\nC26セレナに装着。風切り音無し。 キャンプ道具積載量アップ。 ミニバンだと乗せおろしが大変。 スタンダードで無難。', '柔らかめの生地感ですごく良かったです\n\n先ほど到着したばかりで、妻に新年プレゼントの為に買いました。柔らかめの生地感ですごく良かったです。お値段も高くないし、良かったです。今後も利用するので、よろしくお願いします。', '大好きな香り！\n\n部屋には定期的に噴射する他社の芳香剤を置いていますが、これは人感センサーなのでトイレに置いています！人感センサーなので、トイレを使用した時だけいい香りにしてくれて無駄がありませんし、匂いも私の大好きな匂いでトイレがとてと心地よく感じられます！ 香りの持続力はありませんが、トイレに入ったら瞬時に噴射してくれるのでいつもいい香りをかいでます。', '品質が悪くなった！？\n\nリピーターです。品質が落ちたと思います。浴室に取付けて3ヶ月、既に鏡の淵の裏側から腐食が見られます。また、家族の身長によって上下に向きを変えるのですが、たびたび吸盤から鏡を止めているプラスチックボール部が外れて落下します。以前の物も落下はありましたが、吸盤のボール受け部分が浅くなったのか、ボールが大きくなったのかは古い方を捨てたので比較出来ませんが、新しいのにもかかわらず頻繁に落ちます。強く押し込んでも浮いて見えます。鏡が割れそうなほど強く押し込んでいるのですが。 まあ、落下しても淵のプラスチックの曲面が上手くショックを吸収するように作られている様で、以前のものは鏡自体は最後まで割れませんでした。経年で淵のプラスチックが硬化し、落下のたびにプラスチックの淵が割れていきました。ちなみに、浴室乾燥機はなく直射日光も当たらない環境での利用です。', 'スピード、名作です\n\nかなりの値引き時に購入。もともとDVD持っていたのですが、セットだったので再購入。満足の採用です。', 'コスパ良き\n\n物はいいけど３つ中１つの支えの１つが割れていた。ショートのウィッグを掛けるぶんには問題ないのでそのままつかっているけれど、少し残念なので星3。割れていない２つに関してはとても良い。総合的に見て、たまたま私が外れを引いたとしてもコスパは良いと思う。', '値段相応\n\n予想範囲内のコピー品です。予想の範囲内なので可ですが。 商品タイトルの「3色入り」（グリーン、ブルー、グレー）は意味不明、 コット布地がまさかの購入カラー+別色3色入り？！と少し期待しましたが購入色（ブラック）のみでした。 それと初出し時にも関わらず、コット生地には全体に埃まみれでした（数ヶ月の展示品にくらいの） コロコロしましたが印象はよくないです。生地の切りっぱなしもコピー品としての風格満点です。 今回はタイムセールにて購入ですが商品メーカーとAmazonタイムセールの品質のイメージがさらに悪くなりました。', '色形は良いが、ひものリングがはずれやすい\n\n値段的には色も形も履き心地もバランス良くつくられており問題ないのですが、気に入って履き続けていたところ、約3ヶ月ほどでひもを通すリングが本体から2つもはずれてしまい、不便さはないのですが、なんとなく残念な気がしています。今まであまりリングが外れるという靴を履いたことがないので、これにはちょっと疑問を感じました。', '早く届きました\n\n今のところ、特に問題なく使用しております。', '美味しくいただきました。\n\n美味しくいただきました。もう少しキュウリやダイコンよりも今の時期は白菜やレタスがあると助かりますね', 'ヒト由来の乳酸菌\n\n体にもよさそうで値段も安いので喜んで食べてましたが、 ふと、「ヒト由来」って何よ？と思い調べてみました。 製品ホームページにも詳しくは書いてないですが、 実は・・・から採取、分離、培養してるそうです。 お客様相談室にも確認しました。 うーーん。', 'お得感。ありました。\n\n温かそうで可愛いです。3.1kgチワワでMサイズで大丈夫でした。梱包も到着日も満足しています。', '商品がちゃんと届きません！\n\n定期お届け便でこの商品を購入しましたが、とにかく配送業者がいい加減で在宅してるのに不在票だけポストに入れて帰る。再配達依頼の電話に出ない。電話に出ても「はい。行きます。」と言ったっきり来ない等々で今月２１日到着予定が２７日になっても届きません。amazonに確認したところ配送業者の変更は出来ないとの事でしたのでクレーム入れてキャンセルしました。 どんなに良い商品でも届かないと意味がありません！', '梱包丁寧。メダカ元気。\n\n何匹かは到着した時には死んでいると思っていたけどそんな事はなく凄く元気でした。 今は卵から赤ちゃんが誕生しています。', 'チェーンがね\n\n思ったよりチェーンが長かったので、4つです', '使える\n\n風邪で回るから片側の日焼けを防げる。取り込みやすく干しやすい。 幅が狭いのが少し残念ですが、満足。', 'スーツとコートに使っています\n\nほこりや匂いが服にうつらないよう、こちらの商品を使わせて頂いています。１枚だけすぐ破れましたが、この値段なので仕方ないと割り切りました。全体的には満足している商品です。', '大きい！食パン4枚焼ける。\n\n庫内が広くて大きな物の調理ができて良いです。つまみが大きくて掴みにくい。', '質感、色合いが良い感じ\n\n質感、材質の感じ、色合いなど期待通りでした。', '配送で\n\n缶がベッコリ凹んでた、梱包に気をつけて欲しい。他の物も箱破損してた。', 'モバイルバッテリーでのレビュー\n\n風量が弱いです。 5ボルトでは空調服内に空気が入る程度です。 配線を加工して7.4ボルトで回してみると、やっと使えるかなって程度。 画像をよく見ると、風量の目安が書いてあります。 他の製品と比較して納得してから買った方がいいです。千円や二千円ケチって失敗でした。', '寿命は半年\n\nブラーバの使用は毎日フル稼働で、徐々に稼働時間が減り、約半年で更に悪化、当初の稼働時間の半分以下となって寿命のようです。 いままで4回ぐらいこの手の非純正バッテリーを使用してきましたが、大体持っても半年程度でこれも同様でした。 中には３ヶ月程度で終わるような更に品質の悪い物もあるので、まだマシだったと諦めます。', 'とても好きです、色がきれいで、伸縮レバーのデザインが、小さなリュックに入れることがで\n\nきれいなので、携帯に便利な収納袋がありますが、自分の選択によって固定された位置を調節して、つまみを締めたり、ボタンのデザインも可愛いです。', 'コスパで選んで後悔\n\nとにかく動作が重く、書き込み処理速度が遅い。 書き込み時のカタカタといった音や、振動も他のものと比にならないです。 特に書き込み時は音がしたりしなかったりですぐに壊れそうで不安。 コスパを求める人以外はオススメできません。', '面白くない\n\n僕のおばちゃんが面白くないと言ってました､おじいちゃんは見たくないと言ってました。', '金具が1カ月で壊れた\n\n使い始めて約1カ月。まず金具が壊れた。主にリュックとして使っていたので使えなくなってしまった。あと他のレビューにも書いてありましたがファスナー開け閉めする時に内側の生地を挟んでしまうことが頻繁に起こる。これはイラッとする。大きさとか申し分無いのに…。', '十分使用に耐えます。\n\n不具合がありましたが、メールでの対応が素早く、すぐに代替え分を送ってくださり、安心して取引ができました。 AV、2系統はとても便利です。前と後ろにカメラを付けているので、リモコン1つで切り替わり、すぐに見られるようになります。画面の明るさも十分あり昼間でもよく見えます。', '不良品が届きました。\n\n不良品でした。ネジが馬鹿になっていて、入らないし、空気を入れてみても漏れるしで、また新しいの買わないとですね。お金の無駄になってかなりショックです。', '小学生でも組み立て可能、だけどちょっと重い\n\n小学5年生の息子の遊び用、自主練習用に購入。なんとか一人で組み立てられ一安心。試合球を蹴り込んでも安定していてしっかり出来ています。そのせいか重量があり、5年生が持ち運ぶのは少し大変そうです。もう少し軽ければ星5でしょうか。', '渡り廊下に貼り出された修学旅行の思い出写真\n\nファン目線でも 深イイかウーンかと言えば ウーンです なんか修学旅行あとの 渡り廊下で貼り出された写真を番号を記入して購入した みたいな感じ 影山氏は最後の方で 修学旅行に行けず誰も居ない教室で自習中みたいなコンセプトか？ ランジェリーにしろ水着にしろ 中途半端過ぎましたね。']
# [2, 4, 3, 1, 4, 2, 1, 2, 3, 2, 2, 3, 0, 3, 3, 2, 3, 2, 4, 0, 1, 1, 4, 1, 0, 1, 4, 0, 3, 1]
#
# ^^^^^^^^^^ 1件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 無難な一品
#
# C26セレナに装着。風切り音無し。 キャンプ道具積載量アップ。 ミニバンだと乗せおろしが大変。 スタンダードで無難。
# --- 実際の評価 ---
# 2
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.1円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LEeM6LxNYI5meVN5dLHetgWlvo', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='2', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780424, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=439, total_tokens=440, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 2
#
# ^^^^^^^^^^ 2件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 柔らかめの生地感ですごく良かったです
#
# 先ほど到着したばかりで、妻に新年プレゼントの為に買いました。柔らかめの生地感ですごく良かったです。お値段も高くないし、良かったです。今後も利用するので、よろしくお願いします。
# --- 実際の評価 ---
# 4
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.1円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LF1xeaZ7A37N1K1qJlvgZTKD5W', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='4', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780425, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=460, total_tokens=461, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 4
#
# ^^^^^^^^^^ 3件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 大好きな香り！
#
# 部屋には定期的に噴射する他社の芳香剤を置いていますが、これは人感センサーなのでトイレに置いています！人感センサーなので、トイレを使用した時だけいい香りにしてくれて無駄がありませんし、匂いも私の大好きな匂いでトイレがとてと心地よく感じられます！ 香りの持続力はありませんが、トイレに入ったら瞬時に噴射してくれるのでいつもいい香りをかいでます。
# --- 実際の評価 ---
# 3
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.12円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LF8GnIWYohzvsXWdTsWpzJqTp1', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780425, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=523, total_tokens=524, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 3
#
# ^^^^^^^^^^ 4件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 品質が悪くなった！？
#
# リピーターです。品質が落ちたと思います。浴室に取付けて3ヶ月、既に鏡の淵の裏側から腐食が見られます。また、家族の身長によって上下に向きを変えるのですが、たびたび吸盤から鏡を止めているプラスチックボール部が外れて落下します。以前の物も落下はありましたが、吸盤のボール受け部分が浅くなったのか、ボールが大きくなったのかは古い方を捨てたので比較出来ませんが、新しいのにもかかわらず頻繁に落ちます。強く押し込んでも浮いて見えます。鏡が割れそうなほど強く押し込んでいるのですが。 まあ、落下しても淵のプラスチックの曲面が上手くショックを吸収するように作られている様で、以前のものは鏡自体は最後まで割れませんでした。経年で淵のプラスチックが硬化し、落下のたびにプラスチックの淵が割れていきました。ちなみに、浴室乾燥機はなく直射日光も当たらない環境での利用です。
# --- 実際の評価 ---
# 1
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.16円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LGMd9SNAIt5qLeN8iqde6qKvMF', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='1', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780426, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=691, total_tokens=692, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 1
#
# ^^^^^^^^^^ 5件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# スピード、名作です
#
# かなりの値引き時に購入。もともとDVD持っていたのですが、セットだったので再購入。満足の採用です。
# --- 実際の評価 ---
# 4
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.1円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LGnuaR8YOogDaTWtTCjMiOeGDD', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='4', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780426, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=426, total_tokens=427, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 4
#
# ^^^^^^^^^^ 6件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# コスパ良き
#
# 物はいいけど３つ中１つの支えの１つが割れていた。ショートのウィッグを掛けるぶんには問題ないのでそのままつかっているけれど、少し残念なので星3。割れていない２つに関してはとても良い。総合的に見て、たまたま私が外れを引いたとしてもコスパは良いと思う。
# --- 実際の評価 ---
# 2
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.11円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LGrjAOIW0JElQtNcNC8hKtnBQA', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780426, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=490, total_tokens=491, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 3
#
# ^^^^^^^^^^ 7件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 値段相応
#
# 予想範囲内のコピー品です。予想の範囲内なので可ですが。 商品タイトルの「3色入り」（グリーン、ブルー、グレー）は意味不明、 コット布地がまさかの購入カラー+別色3色入り？！と少し期待しましたが購入色（ブラック）のみでした。 それと初出し時にも関わらず、コット生地には全体に埃まみれでした（数ヶ月の展示品にくらいの） コロコロしましたが印象はよくないです。生地の切りっぱなしもコピー品としての風格満点です。 今回はタイムセールにて購入ですが商品メーカーとAmazonタイムセールの品質のイメージがさらに悪くなりました。
# --- 実際の評価 ---
# 1
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.13円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LHSHN3IwSSB2mtXJ7FH31ERFYM', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='1', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780427, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=567, total_tokens=568, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 1
#
# ^^^^^^^^^^ 8件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 色形は良いが、ひものリングがはずれやすい
#
# 値段的には色も形も履き心地もバランス良くつくられており問題ないのですが、気に入って履き続けていたところ、約3ヶ月ほどでひもを通すリングが本体から2つもはずれてしまい、不便さはないのですが、なんとなく残念な気がしています。今まであまりリングが外れるという靴を履いたことがないので、これにはちょっと疑問を感じました。
# --- 実際の評価 ---
# 2
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.12円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LHSZLsrQDH6XZDBR7c2tLJGjw7', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='2', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780427, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=514, total_tokens=515, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 2
#
# ^^^^^^^^^^ 9件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 早く届きました
#
# 今のところ、特に問題なく使用しております。
# --- 実際の評価 ---
# 3
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.09円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LHSmBPK82fo2XKLgniTEt8J5K5', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780427, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=402, total_tokens=403, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 3
#
# ^^^^^^^^^^ 10件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 美味しくいただきました。
#
# 美味しくいただきました。もう少しキュウリやダイコンよりも今の時期は白菜やレタスがあると助かりますね
# --- 実際の評価 ---
# 2
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.1円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LIY5B70taT6A1GLy2XLzfmdPjO', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780428, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=429, total_tokens=430, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 3
#
# ^^^^^^^^^^ 11件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# ヒト由来の乳酸菌
#
# 体にもよさそうで値段も安いので喜んで食べてましたが、 ふと、「ヒト由来」って何よ？と思い調べてみました。 製品ホームページにも詳しくは書いてないですが、 実は・・・から採取、分離、培養してるそうです。 お客様相談室にも確認しました。 うーーん。
# --- 実際の評価 ---
# 2
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.11円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LI4o2HRhjGASzWQN5Gu6Wa8EEa', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='2', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780428, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=481, total_tokens=482, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 2
#
# ^^^^^^^^^^ 12件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# お得感。ありました。
#
# 温かそうで可愛いです。3.1kgチワワでMサイズで大丈夫でした。梱包も到着日も満足しています。
# --- 実際の評価 ---
# 3
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.1円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LJ3s3YVsV7wwBrSzuFFKIiqDX3', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780429, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=427, total_tokens=428, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 3
#
# ^^^^^^^^^^ 13件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 商品がちゃんと届きません！
#
# 定期お届け便でこの商品を購入しましたが、とにかく配送業者がいい加減で在宅してるのに不在票だけポストに入れて帰る。再配達依頼の電話に出ない。電話に出ても「はい。行きます。」と言ったっきり来ない等々で今月２１日到着予定が２７日になっても届きません。amazonに確認したところ配送業者の変更は出来ないとの事でしたのでクレーム入れてキャンセルしました。 どんなに良い商品でも届かないと意味がありません！
# --- 実際の評価 ---
# 0
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.12円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LJ5yf5CqgZdKFvmTsJAX2uUrDm', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='0', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780429, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=528, total_tokens=529, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 0
#
# ^^^^^^^^^^ 14件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 梱包丁寧。メダカ元気。
#
# 何匹かは到着した時には死んでいると思っていたけどそんな事はなく凄く元気でした。 今は卵から赤ちゃんが誕生しています。
# --- 実際の評価 ---
# 3
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.1円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LJbSlJoWH7lDA6Ubjr83V2OTtF', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780429, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=440, total_tokens=441, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 3
#
# ^^^^^^^^^^ 15件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# チェーンがね
#
# 思ったよりチェーンが長かったので、4つです
# --- 実際の評価 ---
# 3
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.09円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LKEAfvV1khCHOvqcsiGSPJCw5j', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='4', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780430, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=403, total_tokens=404, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 4
#
# ^^^^^^^^^^ 16件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 使える
#
# 風邪で回るから片側の日焼けを防げる。取り込みやすく干しやすい。 幅が狭いのが少し残念ですが、満足。
# --- 実際の評価 ---
# 2
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.1円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LKqwxSqCqmTyp45mPq9AtudpFm', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780430, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=432, total_tokens=433, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 3
#
# ^^^^^^^^^^ 17件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# スーツとコートに使っています
#
# ほこりや匂いが服にうつらないよう、こちらの商品を使わせて頂いています。１枚だけすぐ破れましたが、この値段なので仕方ないと割り切りました。全体的には満足している商品です。
# --- 実際の評価 ---
# 3
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.1円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LLNTsExicZG0Sv3yP44nDW6fjh', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780431, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=453, total_tokens=454, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 3
#
# ^^^^^^^^^^ 18件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 大きい！食パン4枚焼ける。
#
# 庫内が広くて大きな物の調理ができて良いです。つまみが大きくて掴みにくい。
# --- 実際の評価 ---
# 2
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.1円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LMWq1ZydGASF64AGCQzqWDyMNs', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780432, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=431, total_tokens=432, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 3
#
# ^^^^^^^^^^ 19件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 質感、色合いが良い感じ
#
# 質感、材質の感じ、色合いなど期待通りでした。
# --- 実際の評価 ---
# 4
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.09円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LMzYFDkmkzCtEfUPQf4lYzLQdt', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780432, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=413, total_tokens=414, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 3
#
# ^^^^^^^^^^ 20件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 配送で
#
# 缶がベッコリ凹んでた、梱包に気をつけて欲しい。他の物も箱破損してた。
# --- 実際の評価 ---
# 0
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.1円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LMGYji7DKVqdKfk6DD5BsPyUvv', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='1', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780432, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=423, total_tokens=424, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 1
#
# ^^^^^^^^^^ 21件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# モバイルバッテリーでのレビュー
#
# 風量が弱いです。 5ボルトでは空調服内に空気が入る程度です。 配線を加工して7.4ボルトで回してみると、やっと使えるかなって程度。 画像をよく見ると、風量の目安が書いてあります。 他の製品と比較して納得してから買った方がいいです。千円や二千円ケチって失敗でした。
# --- 実際の評価 ---
# 1
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.16円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LNYOlTmwUTZOTUzN7bxwct0KW6', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='レビュー文: 風量が弱いです。 5ボルトでは空調服内に空気が入る程度です。 配線を加工して7.4ボルトで回してみると、やっと使えるかなって程度。 画像をよく見ると、風量の目安が書いてあります。 他の製品と比較して納得してから買った方がいいです。千円や二千円ケチって失敗でした。\n1', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780433, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=104, prompt_tokens=495, total_tokens=599, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# レビュー文: 風量が弱いです。 5ボルトでは空調服内に空気が入る程度です。 配線を加工して7.4ボルトで回してみると、やっと使えるかなって程度。 画像をよく見ると、風量の目安が書いてあります。 他の製品と比較して納得してから買った方がいいです。千円や二千円ケチって失敗でした。
# 1
# --- Error ---
# 回答がint型に変換できませんでした。
#
# ^^^^^^^^^^ 22件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 寿命は半年
#
# ブラーバの使用は毎日フル稼働で、徐々に稼働時間が減り、約半年で更に悪化、当初の稼働時間の半分以下となって寿命のようです。 いままで4回ぐらいこの手の非純正バッテリーを使用してきましたが、大体持っても半年程度でこれも同様でした。 中には３ヶ月程度で終わるような更に品質の悪い物もあるので、まだマシだったと諦めます。
# --- 実際の評価 ---
# 1
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.12円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LO0Yu4l3KlvU82a1L0aV37XRvo', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='1', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780434, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=513, total_tokens=514, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 1
#
# ^^^^^^^^^^ 23件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# とても好きです、色がきれいで、伸縮レバーのデザインが、小さなリュックに入れることがで
#
# きれいなので、携帯に便利な収納袋がありますが、自分の選択によって固定された位置を調節して、つまみを締めたり、ボタンのデザインも可愛いです。
# --- 実際の評価 ---
# 4
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.14円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LP8CvOdpn2DYLY3vEmwqkGy6Ac', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='レビュー文: とても好きです、色がきれいで、伸縮レバーのデザインが、小さなリュックに入れることができるので、携帯に便利な収納袋がありますが、自分の選択によって固定された位置を調節して、つまみを締めたり、ボタンのデザインも可愛いです。  \n評価: 4', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780435, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=85, prompt_tokens=465, total_tokens=550, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# レビュー文: とても好きです、色がきれいで、伸縮レバーのデザインが、小さなリュックに入れることができるので、携帯に便利な収納袋がありますが、自分の選択によって固定された位置を調節して、つまみを締めたり、ボタンのデザインも可愛いです。
# 評価: 4
# --- Error ---
# 回答がint型に変換できませんでした。
#
# ^^^^^^^^^^ 24件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# コスパで選んで後悔
#
# とにかく動作が重く、書き込み処理速度が遅い。 書き込み時のカタカタといった音や、振動も他のものと比にならないです。 特に書き込み時は音がしたりしなかったりですぐに壊れそうで不安。 コスパを求める人以外はオススメできません。
# --- 実際の評価 ---
# 1
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.11円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LRSBEKNiLEWyNikfHroh98PcVf', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='1', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780437, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=489, total_tokens=490, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 1
#
# ^^^^^^^^^^ 25件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 面白くない
#
# 僕のおばちゃんが面白くないと言ってました､おじいちゃんは見たくないと言ってました。
# --- 実際の評価 ---
# 0
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.09円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LRepOY087Q4WFmnfdZhXsMY09R', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='1', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780437, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=416, total_tokens=417, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 1
#
# ^^^^^^^^^^ 26件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 金具が1カ月で壊れた
#
# 使い始めて約1カ月。まず金具が壊れた。主にリュックとして使っていたので使えなくなってしまった。あと他のレビューにも書いてありましたがファスナー開け閉めする時に内側の生地を挟んでしまうことが頻繁に起こる。これはイラッとする。大きさとか申し分無いのに…。
# --- 実際の評価 ---
# 1
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.11円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LSAhaherXnKDsIT2xhtKSmzxOK', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='1', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780438, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=493, total_tokens=494, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 1
#
# ^^^^^^^^^^ 27件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 十分使用に耐えます。
#
# 不具合がありましたが、メールでの対応が素早く、すぐに代替え分を送ってくださり、安心して取引ができました。 AV、2系統はとても便利です。前と後ろにカメラを付けているので、リモコン1つで切り替わり、すぐに見られるようになります。画面の明るさも十分あり昼間でもよく見えます。
# --- 実際の評価 ---
# 4
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.11円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LSStX3a4IRDPq93lsNho1HvEWk', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='4', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780438, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=496, total_tokens=497, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 4
#
# ^^^^^^^^^^ 28件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 不良品が届きました。
#
# 不良品でした。ネジが馬鹿になっていて、入らないし、空気を入れてみても漏れるしで、また新しいの買わないとですね。お金の無駄になってかなりショックです。
# --- 実際の評価 ---
# 0
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.1円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LT1D01wH4hnjvdxDfShLsLXl41', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='0', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780439, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=448, total_tokens=449, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 0
#
# ^^^^^^^^^^ 29件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 小学生でも組み立て可能、だけどちょっと重い
#
# 小学5年生の息子の遊び用、自主練習用に購入。なんとか一人で組み立てられ一安心。試合球を蹴り込んでも安定していてしっかり出来ています。そのせいか重量があり、5年生が持ち運ぶのは少し大変そうです。もう少し軽ければ星5でしょうか。
# --- 実際の評価 ---
# 3
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.11円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LT8RXxdnE9LeRbd7ofReyUcsMg', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='3', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780439, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=492, total_tokens=493, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 3
#
# ^^^^^^^^^^ 30件目のレビュー ^^^^^^^^^^
# --- レビュー文 ---
# 渡り廊下に貼り出された修学旅行の思い出写真
#
# ファン目線でも 深イイかウーンかと言えば ウーンです なんか修学旅行あとの 渡り廊下で貼り出された写真を番号を記入して購入した みたいな感じ 影山氏は最後の方で 修学旅行に行けず誰も居ない教室で自習中みたいなコンセプトか？ ランジェリーにしろ水着にしろ 中途半端過ぎましたね。
# --- 実際の評価 ---
# 1
# 使用したモデル: gpt-4o-mini-2024-07-18, 料金: 0.12円
# --- ChatGPTの回答 ---
# ChatCompletion(id='chatcmpl-AQ5LUWd56QAl60jhlHqcYjVGcjCLB', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='1', role='assistant', function_call=None, tool_calls=None, refusal=None), logprobs=None)], created=1730780440, model='gpt-4o-mini-2024-07-18', object='chat.completion', system_fingerprint='fp_0ba0d124f1', usage=CompletionUsage(completion_tokens=1, prompt_tokens=510, total_tokens=511, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))
# 1
# 合計金額: 3.310000000000001円

# %%
print("--- 実際の評価 ---")
print(label_list)
print("--- 予測した評価--- ")
print(predict_label_list)

# 評価
## 実際の評価と予測した評価の差の合計を評価値 (loss)
## 予測した評価が-1（出力形式のエラー）の場合は+6

validation_score = 0 # 評価値
correct_answer = 0 # 正解数
for actual, predict in zip(label_list, predict_label_list):
    if not actual == predict:
        if predict == -1:
            validation_score += 6
            continue
        validation_score += abs(actual - predict)
    else:
        correct_answer += 1
print("\n--- 正答率 ---")
print(f"{correct_answer/len(label_list)*100} %")
print("--- 評価値 (低いほうが良い結果) ---")
print(validation_score)
# Out:
# --- 実際の評価 ---
# [2, 4, 3, 1, 4, 2, 1, 2, 3, 2, 2, 3, 0, 3, 3, 2, 3, 2, 4, 0, 1, 1, 4, 1, 0, 1, 4, 0, 3, 1]
# --- 予測した評価---
# [2, 4, 3, 1, 4, 3, 1, 2, 3, 3, 2, 3, 0, 3, 4, 3, 3, 3, 3, 1, -1, 1, -1, 1, 1, 1, 4, 0, 3, 1]
#
# --- 正答率 ---
# 66.66666666666666 %
# --- 評価値 (低いほうが良い結果) ---
# 20

# %% [markdown]
# ## Extra課題

# %%
user_prompt = "2泊3日の札幌観光旅行のプランを考えてください。"

# Extra課題
system_prompt = """
ユーザの質問に回答してください。
"""

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": user_prompt
        },
    ],
    model="gpt-3.5-turbo",
)

# %%
print("--- 全体の出力 ---")
print(response)

calculate_credit(model, response.usage.prompt_tokens, response.usage.completion_tokens)

print()
print("--- 質問 ---")
print(user_prompt)
print("--- 回答 ---")
print(response.choices[0].message.content)
